# %% [markdown]
# # 01 Data Ingestion
#
# Day 1 notebook wrapper for the ETL pipeline. The source of truth is `../scripts/etl_pipeline.py`.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.append(str(ROOT / 'scripts'))

import etl_pipeline
etl_pipeline.main()
